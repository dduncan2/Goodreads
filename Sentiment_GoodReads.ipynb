# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel("good_reads_write_underscore.xlsx")

# %%
df['polarity'] = df.apply(lambda x: TextBlob(x[np.str('review')]).sentiment.polarity, axis=1)

# %%
df['subjectivity'] = df.apply(lambda x: TextBlob(x[np.str('review')]).sentiment.subjectivity, axis=1)

# %%
df.head(25)
# Out:
#                    book_title                       Book_series  book_rating  \
# 0   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 1   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 2   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 3   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 4   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 5   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 6   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 7   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 8   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 9   A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# 10  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)         4.51
# ...

# %%
 from textblob import TextBlob

# %%
review = TextBlob([[df.review]])
review.sentiment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-88e80b68e672> in <module>()
# ----> 1 review = TextBlob([[df.review]])
#       2 review.sentiment
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in __init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     368         if not isinstance(text, basestring):
#     369             raise TypeError('The `text` argument passed to `__init__(text)` '
# --> 370                             'must be a string, not {0}'.format(type(text)))
#     371         if clean_html:
#     372             raise NotImplementedError("clean_html has been deprecated. "
#
# TypeError: The `text` argument passed to `__init__(text)` must be a string, not <class 'list'>

# %%
review.sentiment.polarity
# Out:
# 0.6000000000000001

# %%
review.sentiment.subjectivity
# Out:
# 0.9
